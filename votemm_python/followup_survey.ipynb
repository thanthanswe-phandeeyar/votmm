# %%
import pymongo
import pandas as pd 
from glob import glob 
import os
import numpy as np

# %%
# Update here

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["Votemm_20201014"]

# %%
print(myclient.list_database_names()) # Check a specific database by name

# %%
#Check if votemm exists
dblist = myclient.list_database_names()
if "Votemm_20201014" in dblist:
  print("Votemm_20201014 exists.")

# %%
# Update here

vote_name =myclient.Votemm_20201014

voters = vote_name.voters

samples = voters.find().sort("_id",pymongo.ASCENDING)

voters_df = pd.DataFrame(samples)

voters_df.shape

# %%
vote_dataframe = pd.DataFrame (voters_df, columns = ['client_id','browser','os','gender','age','is_vote','not_vote_reason','pwd','ethnicity','regilion','submitSurvey'])

# %%
votemm_db ='Votemm_20201014/followup_survey/'  # replace db-name 

votemm_folder = '../votemm_python/votemm/{}'.format(votemm_db) #create a folder with a respective database folder's name.


if not os.path.exists(votemm_folder):
    os.makedirs(votemm_folder)
else:votemm_path =votemm_folder

# %%
##Followup_Survey 

Followup_Survey = vote_name.followup_survey

find = Followup_Survey.inventory.find()

Followup_Survey_table = Followup_Survey.find().sort("_id",pymongo.ASCENDING)

Followup_Survey_dataframe = pd.DataFrame(Followup_Survey_table)

Followup_Survey_dataframe.shape

Followup_Survey_dataframe.columns

# %%
import ast 
Followup_Survey_df = pd.merge(vote_dataframe[['client_id','gender']],Followup_Survey_dataframe)
followup_survey_df = Followup_Survey_df[['client_id','gender','answers','count']]

know_list=[]

use_count=useless_count=0

useful=[]

female_d_party=female_survey_2020_party=female_hluttaw_party=female_media = female_democracy_puzzle= female_democracy_usage=female_other_resources=female_ten_mark_puzzle=0
male_d_party=male_survey_2020_party=male_hluttaw_party=male_media = male_democracy_puzzle= male_democracy_usage=male_other_resources=male_ten_mark_puzzle=0
other_d_party=other_survey_2020_party=other_hluttaw_party=other_media = other_democracy_puzzle= other_democracy_usage=other_other_resources=other_ten_mark_puzzle=0
no_info_d_party=no_info_survey_2020_party=no_info_hluttaw_party=no_info_media = no_info_democracy_puzzle= no_info_democracy_usage=no_info_other_resources=no_info_ten_mark_puzzle=0


know_cols=['Gender','Vote MM Facebook Page မှ','ရွေးကောက်ပွဲဆိုင်ရာသင်တန်းများမှ','သတင်းထဲမှာတွေ့လို့','အခြား Facebook Page မှ']

female_gender=male_gender=other_gender=no_info_gender =''

female_votemm=female_elect_course=female_news_found=female_another_fb_page=0
male_votemm=male_elect_course=male_news_found=male_another_fb_page=0
other_votemm=other_elect_course=other_news_found=other_another_fb_page=0
no_info_votemm=no_info_elect_course=no_info_news_found=no_info_another_fb_page=0

female_useless_count=female_use_count=0
male_useless_count=male_use_count=0
other_useless_count=other_use_count=0
no_info_useless_count=no_info_use_count=0

votemm_useful_cols =['Gender','အသုံးမဝင်ပါ','အသုံးဝင်ပါတယ်']


votemm_useful_list =[]


useful_role_cols=['Gender','စိတ်ကူးထဲကပါတီ', '၂၀၂၀ တွင်ပါဝင်ယှဉ်ပြိုင်မည့်ပါတီများစားရင်း', 'လွှတ်တော်နှင့်ရွေးကောက်ပွဲ', 'သတင်း၊မီဒီယာ', 'ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ ဉာဏ်စမ်း', 'ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ အသုံးအနှုန်းများ','အခြားအရင်းအမြစ်များ','ဆယ်မှတ် ဉာဏ်စမ်း','ပုံနှင့်ဖော်ပြသောအချက်အလက်များ','တစ်ခုမှအသုံးမဝင်ပါ']
useful_role_list =[]

female_election_2010=female_election_2012=female_election_2015=female_election_2017=female_election_2018=female_election_2019=0
male_election_2010=male_election_2012=male_election_2015=male_election_2017=male_election_2018=male_election_2019=0
other_election_2010=other_election_2012=other_election_2015=other_election_2017=other_election_2018=other_election_2019=0
no_info_election_2010=no_info_election_2012=no_info_election_2015=no_info_election_2017=no_info_election_2018=no_info_election_2019=0

votemm_cols=['Gender','၂၀၁၀ အထွေထွေရွေးကောက်ပွဲ','၂၀၁၂ ကြားဖြတ်ရွေးကောက်ပွဲ','၂၀၁၅ အထွေထွေရွေးကောက်ပွဲ','၂၀၁၇ ကြားဖြတ်ရွေးကောက်ပွဲ',"၂၀၁၈ ကြားဖြတ်ရွေးကောက်ပွဲ",'၂၀၁၉ ရန်ကုန်စည်ပင်ရွေးကောက်ပွဲ']


usefulpages_true=usefulpages_false=votemm_before_list=[]

female_d_party=female_survey_2020_party=female_hluttaw_party=female_media = female_democracy_puzzle= female_democracy_usage=female_other_resources=female_ten_mark_puzzle=female_pic_facts=female_none_use=0
male_d_party=male_survey_2020_party=male_hluttaw_party=male_media = male_democracy_puzzle= male_democracy_usage=male_other_resources=male_ten_mark_puzzle=male_pic_facts=male_none_use=0
other_d_party=other_f_survey_2020_party=other_hluttaw_party=other_media = other_democracy_puzzle= other_democracy_usage=other_other_resources=other_ten_mark_puzzle=other_pic_facts=other_none_use=0
no_info_d_party=no_info_survey_2020_party=no_info_hluttaw_party=no_info_media = no_info_democracy_puzzle= no_info_democracy_usage=no_info_other_resources=no_info_ten_mark_puzzle=no_info_pic_facts=no_info_none_use=0


covid_political_news_list=[]
covid_political_news_cols =['Gender','ပိုပြီးရှာဖြစ်','အရင်အတိုင်း','အရင်ကလောက်မရှာဖြစ်']

more_than_search_female= normal_search_female=no_more_search_female=0
more_than_search_male= normal_search_male=no_more_search_male=0
more_than_search_other= normal_search_other=no_more_search_other=0
more_than_search_no_info= normal_search_no_info=no_more_search_no_info=0


female_election_2010=female_election_2012=female_election_2015=female_election_2017=female_election_2018=female_election_2019=female_no_vote=0
male_election_2010=male_election_2012=male_election_2015=male_election_2017=male_election_2018=male_election_2019=male_no_vote=0
other_election_2010=other_election_2012=other_election_2015=other_election_2017=other_election_2018=other_election_2019=other_no_vote=0
no_info_election_2010=no_info_election_2012=no_info_election_2015=no_info_election_2017=no_info_election_2018=no_info_election_2019=no_info_no_vote=0

beforeVotemm_cols=['Gender','၂၀၁၀ အထွေထွေရွေးကောက်ပွဲ','၂၀၁၂ ကြားဖြတ်ရွေးကောက်ပွဲ','၂၀၁၅ အထွေထွေရွေးကောက်ပွဲ','၂၀၁၇ ကြားဖြတ်ရွေးကောက်ပွဲ',"၂၀၁၈ ကြားဖြတ်ရွေးကောက်ပွဲ",'၂၀၁၉ ရန်ကုန်စည်ပင်ရွေးကောက်ပွဲ','မည်သည့်ရွေးကောက်ပွဲမှ မပေးဖူးပါ']

beforeVotemm_list=[]

female_follow_before=female_like_before=female_comment_before=female_share_before=female_nopost_before=0
male_follow_before=male_like_before=male_comment_before=male_share_before=male_nopost_before=0
other_follow_before=other_like_before=other_comment_before=other_share_before=other_nopost_before=0
no_info_follow_before=no_info_like_before=no_info_comment_before=no_info_share_before=no_info_nopost_before=0



beforeVotemmFB_list =[]
beforeVotemmFB_cols=['Gender','စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်','"ကြိုက်" (like လုပ်) ဖြစ်တယ်','"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်','"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်','ဘာမှမလုပ်ဖြစ်ပါ']

female_think_before=female_group_discussion_before=female_reveal_before=female_make_decision_before=female_make_encourage_before=female_participate_before=female_none_before=0
male_think_before=male_group_discussion_before=male_reveal_before=male_make_decision_before=male_make_encourage_before=male_participate_before=male_none_before=0
other_think_before=other_group_discussion_before=other_reveal_before=other_make_decision_before=other_make_encourage_before=other_participate_before=other_none_before=0
no_info_think_before=no_info_group_discussion_before=no_info_reveal_before=no_info_make_decision_before=no_info_make_encourage_before=no_info_participate_before=no_info_none_before=0

beforeVotemm_opinion_list =[]
beforeVotemm_opinion_cols=['Gender','စဉ်းစားဖြစ်တယ်','အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်','အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်','မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်','မဲပေးရန်တိုက်တွန်းဖြစ်တယ်','တက်ကြွလှုပ်ရှားဖြစ်တယ်','ဘာမှမလုပ်ဖြစ်ပါ']

female_follow_after=female_like_after=female_comment_after=female_share_after=female_nopost_after=0
male_follow_after=male_like_after=male_comment_after=male_share_after=male_nopost_after=0
other_follow_after=other_like_after=other_comment_after=other_share_after=other_nopost_after=0
no_info_follow_after=no_info_like_after=no_info_comment_after=no_info_share_after=no_info_nopost_after=0

afterVotemmFB_list =[]
afterVotemmFB_cols=['Gender','စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်','"ကြိုက်" (like လုပ်) ဖြစ်တယ်','"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်','"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်','ဘာမှမလုပ်ဖြစ်ပါ']


female_think_after=female_group_discussion_after=female_reveal_after=female_make_decision_after=female_make_encourage_after=female_participate_after=female_none_after=0
male_think_after=male_group_discussion_after=male_reveal_after=male_make_decision_after=male_make_encourage_after=male_participate_after=male_none_after=0
other_think_after=other_group_discussion_after=other_reveal_after=other_make_decision_after=other_make_encourage_after=other_participate_after=other_none_after=0
no_info_think_after=no_info_group_discussion_after=no_info_reveal_after=no_info_make_decision_after=no_info_make_encourage_after=no_info_participate_after=no_info_none_after=0

afterVotemm_opinion_list =[]
afterVotemm_opinion_cols=['Gender','စဉ်းစားဖြစ်တယ်','အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်','အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်','မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်','မဲပေးရန်တိုက်တွန်းဖြစ်တယ်','တက်ကြွလှုပ်ရှားဖြစ်တယ်','ဘာမှမလုပ်ဖြစ်ပါ']


votemm_difficult_list=[]
votemm_difficult_cols=['gender','စိတ်မဝင်စားလို့','အချိန်/ငွေကြေးအခက်အခဲရှိလို့','မိသားစု အသိုင်းအဝိုင်းက အားမပေးလို့','နိုင်ငံရေးအကြောင်း အသိပညာ/အတွေ့အကြုံ အားနည်းလို့','တက်ကြွလှုပ်ရှားသူများနှင့် အချိတ်အဆက်မရှိလို့','အဟန့်အတားမရှိပါ']

female_no_interest=female_time_money_difficult=female_family_disagreed=female_political_vulnerable=female_no_contact=female_no_difficult =0
male_no_interest=male_time_money_difficult=male_family_disagreed=male_political_vulnerable=male_no_contact=male_no_difficult =0
other_no_interest=other_time_money_difficult=other_family_disagreed=other_political_vulnerable=other_no_contact=other_no_difficult =0
no_info_no_interest=no_info_time_money_difficult=no_info_family_disagreed=no_info_political_vulnerable=no_info_no_contact=no_info_no_difficult =0

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    useful=ans_one[1:2]
    for use in useful:
        u=str(use[1:2]).strip('[]')
        if gender =='female' or gender=='Female':  
            if u=="'အသုံးမဝင်ပါ'":
                female_useless_count+=1 
            elif u=="'အသုံးဝင်ပါတယ်'":
                female_use_count+=1  
        elif gender =="male" or gender=='Male':
            if u=="'အသုံးမဝင်ပါ'":
                male_useless_count+=1
            elif u=="'အသုံးဝင်ပါတယ်'":
                male_use_count+=1
        elif gender =='other' or gender=='Other':
            if u=="'အသုံးမဝင်ပါ'":
                other_useless_count+=1 
            elif u=="'အသုံးဝင်ပါတယ်'":
                other_use_count+=1
        else: ### NO Info Count 
            if u=="'အသုံးမဝင်ပါ'":
                no_info_useless_count+=1 
            elif u=="'အသုံးဝင်ပါတယ်'":
                no_info_use_count+=1
votemm_useful_list.append(["Female",female_useless_count,female_use_count])
votemm_useful_list.append(["Male",male_useless_count,male_use_count])
votemm_useful_list.append(["Other",other_useless_count,other_use_count])
votemm_useful_list.append(["No Info",no_info_useless_count,no_info_use_count])

# Number of viewers in useful_useless page

votemm_useful_pd = pd.DataFrame (votemm_useful_list, columns = votemm_useful_cols)
votemm_useful_pd.to_csv(votemm_folder+'followup_useful_useless_by_users.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    ans_one=ast.literal_eval(answer)
    knowFrom=ans_one[0:1]
    for know in knowFrom:
        for k in know[1:2]:
            for k_val in k:
                if gender =='female' or gender=='Female':
                    if k_val=='Vote MM Facebook Page မှ':female_votemm+=1
                    elif k_val=='ရွေးကောက်ပွဲဆိုင်ရာသင်တန်းများမှ':female_elect_course+=1
                    elif k_val=="သတင်းထဲမှာတွေ့လို့":female_news_found+=1
                    elif k_val=="အခြား Facebook Page မှ":female_another_fb_page+=1
                
                elif gender =='male' or gender=='male':
                    if k_val=='Vote MM Facebook Page မှ':male_votemm+=1
                    elif k_val=='ရွေးကောက်ပွဲဆိုင်ရာသင်တန်းများမှ':male_elect_course+=1
                    elif k_val=="သတင်းထဲမှာတွေ့လို့":male_news_found+=1
                    elif k_val=="အခြား Facebook Page မှ":male_another_fb_page+=1

                elif gender =='other' or gender=='other':
                    if k_val=='Vote MM Facebook Page မှ':other_votemm+=1
                    elif k_val=='ရွေးကောက်ပွဲဆိုင်ရာသင်တန်းများမှ':other_elect_course+=1
                    elif k_val=="သတင်းထဲမှာတွေ့လို့":other_news_found+=1
                    elif k_val=="အခြား Facebook Page မှ":other_another_fb_page+=1
                else:
                    if k_val=='Vote MM Facebook Page မှ':no_info_votemm+=1
                    elif k_val=='ရွေးကောက်ပွဲဆိုင်ရာသင်တန်းများမှ':no_info_elect_course+=1
                    elif k_val=="သတင်းထဲမှာတွေ့လို့":no_info_news_found+=1
                    elif k_val=="အခြား Facebook Page မှ":no_info_another_fb_page+=1

know_list.append(['Female',female_votemm,female_elect_course,female_news_found,female_another_fb_page])
know_list.append(['Male',male_votemm,male_elect_course,male_news_found,male_another_fb_page])
know_list.append(['Other',other_votemm,other_elect_course,other_news_found,other_another_fb_page])
know_list.append(['No Info',no_info_votemm,no_info_elect_course,no_info_news_found,no_info_another_fb_page])

# Number of viewers in useful_useless page

votemm_knowForm_pd = pd.DataFrame (know_list, columns = know_cols)
votemm_knowForm_pd.to_csv(votemm_folder+'followup_knowfrom_by_users.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    votemm_useful_role=ans_one[2:3] 
    for p_value in votemm_useful_role:
        for p_val in p_value[1:2]:
            for p in p_val[0:1]:
                if gender=='Female' or gender=='female':
                    if p=='စိတ်ကူးထဲကပါတီ':         
                        female_d_party+=1
                    elif p=='၂၀၂၀ တွင်ပါဝင်ယှဉ်ပြိုင်မည့်ပါတီများစားရင်း':
                        female_survey_2020_party+=1
                    elif p=='လွှတ်တော်နှင့်ရွေးကောက်ပွဲ':
                        female_hluttaw_party+=1
                    elif p=='သတင်း၊မီဒီယာ':
                        female_media+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ ဉာဏ်စမ်း':
                        female_democracy_puzzle+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ အသုံးအနှုန်းများ':
                        female_democracy_usage+=1
                    elif p=='အခြားအရင်းအမြစ်များ':
                        female_other_resources+=1
                    elif p=='ဆယ်မှတ် ဉာဏ်စမ်း':
                        female_ten_mark_puzzle+=1
                    elif p=='ပုံနှင့်ဖော်ပြသောအချက်အလက်များ':
                        female_pic_facts+=1 
                    elif p=='တစ်ခုမှအသုံးမဝင်ပါ':
                        female_none_use+=1  
                elif gender=='male' or gender=='male':
                    if p=='စိတ်ကူးထဲကပါတီ':
                        male_d_party+=1
                    elif p=='၂၀၂၀ တွင်ပါဝင်ယှဉ်ပြိုင်မည့်ပါတီများစားရင်း':
                        male_survey_2020_party+=1
                    elif p=='လွှတ်တော်နှင့်ရွေးကောက်ပွဲ':
                        male_hluttaw_party+=1
                    elif p=='သတင်း၊မီဒီယာ':
                        male_media+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ ဉာဏ်စမ်း':
                        male_democracy_puzzle+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ အသုံးအနှုန်းများ':
                        male_democracy_usage+=1
                    elif p=='အခြားအရင်းအမြစ်များ':
                        male_other_resources+=1
                    elif p=='ဆယ်မှတ် ဉာဏ်စမ်း':
                        male_ten_mark_puzzle+=1
                    elif p=='ပုံနှင့်ဖော်ပြသောအချက်အလက်များ':
                        male_pic_facts+=1 
                    elif p=='တစ်ခုမှအသုံးမဝင်ပါ':
                        male_none_use+=1  
                elif gender=='other' or gender=='Other':
                    if p=='စိတ်ကူးထဲကပါတီ':
                        other_d_party+=1
                    elif p=='၂၀၂၀ တွင်ပါဝင်ယှဉ်ပြိုင်မည့်ပါတီများစားရင်း':
                        other_survey_2020_party+=1
                    elif p=='လွှတ်တော်နှင့်ရွေးကောက်ပွဲ':
                        other_hluttaw_party+=1
                    elif p=='သတင်း၊မီဒီယာ':
                        other_media+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ ဉာဏ်စမ်း':
                        other_democracy_puzzle+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ အသုံးအနှုန်းများ':
                        other_democracy_usage+=1
                    elif p=='အခြားအရင်းအမြစ်များ':
                        other_other_resources+=1
                    elif p=='ဆယ်မှတ် ဉာဏ်စမ်း':
                        other_ten_mark_puzzle+=1
                    elif p=='ပုံနှင့်ဖော်ပြသောအချက်အလက်များ':
                        other_pic_facts+=1 
                    elif p=='တစ်ခုမှအသုံးမဝင်ပါ':
                        other_none_use+=1 
                else:  
                    if p=='စိတ်ကူးထဲကပါတီ':
                        no_info_d_party+=1
                    elif p=='၂၀၂၀ တွင်ပါဝင်ယှဉ်ပြိုင်မည့်ပါတီများစားရင်း':
                        no_info_survey_2020_party+=1
                    elif p=='လွှတ်တော်နှင့်ရွေးကောက်ပွဲ':
                        no_info_hluttaw_party+=1
                    elif p=='သတင်း၊မီဒီယာ':
                        no_info_media+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ ဉာဏ်စမ်း':
                        no_info_democracy_puzzle+=1
                    elif p=='ဒီမိုကရေစီနှင့်ရွေးကောက်ပွဲ အသုံးအနှုန်းများ':
                        no_info_democracy_usage+=1
                    elif p=='အခြားအရင်းအမြစ်များ':
                        no_info_other_resources+=1
                    elif p=='ဆယ်မှတ် ဉာဏ်စမ်း':
                        no_info_ten_mark_puzzle+=1
                    elif p=='ပုံနှင့်ဖော်ပြသောအချက်အလက်များ':
                        no_info_pic_facts+=1 
                    elif p=='တစ်ခုမှအသုံးမဝင်ပါ':
                        no_info_none_use+=1    

votemm_useful_list.append(['Female',female_d_party,female_survey_2020_party,female_hluttaw_party,female_media,female_democracy_puzzle,female_democracy_usage,female_other_resources,female_ten_mark_puzzle,female_pic_facts,female_none_use])

votemm_useful_list.append(['Male',male_d_party,male_survey_2020_party,male_hluttaw_party,male_media,male_democracy_puzzle,male_democracy_usage,male_other_resources,male_ten_mark_puzzle,male_pic_facts,male_none_use])

votemm_useful_list.append(['Other',other_d_party,other_survey_2020_party,other_hluttaw_party,other_media,other_democracy_puzzle,other_democracy_usage,other_other_resources,other_ten_mark_puzzle,other_pic_facts,other_none_use])

votemm_useful_list.append(['No Info',no_info_d_party,no_info_survey_2020_party,no_info_hluttaw_party,no_info_media,no_info_democracy_puzzle,no_info_democracy_usage,no_info_other_resources,no_info_ten_mark_puzzle,no_info_pic_facts,no_info_none_use])

print(votemm_useful_list)
# Number of viewers in useful_useless page

votemm_useful_role_pd = pd.DataFrame(votemm_useful_list, columns = useful_role_cols)
votemm_useful_role_pd.to_csv(votemm_folder+'followup_useful_role.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    covid_political_news=ans_one[3:4]
    for covid_news in covid_political_news:
        for covid in covid_news[1:2]:
            if gender=='female' or gender=='Female':
                if covid=='ပိုပြီးရှာဖြစ်' or covid=='online ပေါ်မှာ ရွေးကောက်ပွဲ/နိုင်ငံရေးသတင်းအချက်အလက်တွေ ပိုပြီးရှာဖြစ်လာတယ်':more_than_search_female+=1
                elif covid=='အရင်အတိုင်း':normal_search_female+=1
                elif covid=='အရင်ကလောက်မရှာဖြစ်':no_more_search_female+=1
            elif gender=='male' or gender=='Male':
                if covid=='ပိုပြီးရှာဖြစ်' or covid=='online ပေါ်မှာ ရွေးကောက်ပွဲ/နိုင်ငံရေးသတင်းအချက်အလက်တွေ ပိုပြီးရှာဖြစ်လာတယ်':more_than_search_male+=1
                elif covid=='အရင်အတိုင်း':normal_search_male+=1
                elif covid=='အရင်ကလောက်မရှာဖြစ်':no_more_search_male+=1
            elif gender=='other' or gender =='Other':
                if covid=='ပိုပြီးရှာဖြစ်' or covid=='online ပေါ်မှာ ရွေးကောက်ပွဲ/နိုင်ငံရေးသတင်းအချက်အလက်တွေ ပိုပြီးရှာဖြစ်လာတယ်':more_than_search_other+=1
                elif covid=='အရင်အတိုင်း':normal_search_other+=1
                elif covid=='အရင်ကလောက်မရှာဖြစ်':no_more_search_other+=1
            else:
                if covid=='ပိုပြီးရှာဖြစ်' or covid=='online ပေါ်မှာ ရွေးကောက်ပွဲ/နိုင်ငံရေးသတင်းအချက်အလက်တွေ ပိုပြီးရှာဖြစ်လာတယ်':more_than_search_no_info+=1
                elif covid=='အရင်အတိုင်း':normal_search_no_info+=1
                elif covid=='အရင်ကလောက်မရှာဖြစ်':no_more_search_no_info+=1

covid_political_news_list.append(['Female',more_than_search_female,normal_search_female,no_more_search_female])
covid_political_news_list.append(['Male',more_than_search_male,normal_search_male,no_more_search_male])
covid_political_news_list.append(['Other',more_than_search_other,normal_search_other,no_more_search_other])
covid_political_news_list.append(['No Info',more_than_search_no_info,normal_search_no_info,no_more_search_no_info])


# Number of viewers in useful_useless page

covid_political_news_pd = pd.DataFrame(covid_political_news_list, columns = covid_political_news_cols)
covid_political_news_pd.to_csv(votemm_folder+'followup_covid_political_news_by_user.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    beforeVotemm=ans_one[4:5]
    for before_vote in beforeVotemm:
        for b_vote in before_vote[1:2]:
            for vote_val in b_vote:
                if gender=='female' or gender=='Female':
                    if vote_val=='၂၀၁၀ အထွေထွေရွေးကောက်ပွဲ':      
                        female_election_2010+=1
                    elif vote_val=='၂၀၁၂ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        female_election_2012+=1
                    elif vote_val=='၂၀၁၅ အထွေထွေရွေးကောက်ပွဲ':
                        female_election_2015+=1
                    elif vote_val=='၂၀၁၇ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        female_election_2017+=1
                    elif vote_val=="၂၀၁၈ ကြားဖြတ်ရွေးကောက်ပွဲ":
                        female_election_2018+=1
                    elif vote_val=='၂၀၁၉ ရန်ကုန်စည်ပင်ရွေးကောက်ပွဲ':
                        female_election_2019+=1
                    elif vote_val=='မည်သည့်ရွေးကောက်ပွဲမှ မပေးဖူးပါ':
                        female_no_vote+=1
                elif gender=='male' or gender=='Male':
                    if vote_val=='၂၀၁၀ အထွေထွေရွေးကောက်ပွဲ':      
                        male_election_2010+=1
                    elif vote_val=='၂၀၁၂ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        male_election_2012+=1
                    elif vote_val=='၂၀၁၅ အထွေထွေရွေးကောက်ပွဲ':
                        male_election_2015+=1
                    elif vote_val=='၂၀၁၇ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        male_election_2017+=1
                    elif vote_val=="၂၀၁၈ ကြားဖြတ်ရွေးကောက်ပွဲ":
                        male_election_2018+=1
                    elif vote_val=='၂၀၁၉ ရန်ကုန်စည်ပင်ရွေးကောက်ပွဲ':
                        male_election_2019+=1
                    elif vote_val=='မည်သည့်ရွေးကောက်ပွဲမှ မပေးဖူးပါ':
                        male_no_vote+=1
                elif gender=='other' or gender=='Other':
                    if vote_val=='၂၀၁၀ အထွေထွေရွေးကောက်ပွဲ':      
                        other_election_2010+=1
                    elif vote_val=='၂၀၁၂ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        other_election_2012+=1
                    elif vote_val=='၂၀၁၅ အထွေထွေရွေးကောက်ပွဲ':
                        other_election_2015+=1
                    elif vote_val=='၂၀၁၇ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        other_election_2017+=1
                    elif vote_val=="၂၀၁၈ ကြားဖြတ်ရွေးကောက်ပွဲ":
                        other_election_2018+=1
                    elif vote_val=='၂၀၁၉ ရန်ကုန်စည်ပင်ရွေးကောက်ပွဲ':
                        other_election_2019+=1
                    elif vote_val=='မည်သည့်ရွေးကောက်ပွဲမှ မပေးဖူးပါ':
                        other_no_vote+=1
                else:
                    if vote_val=='၂၀၁၀ အထွေထွေရွေးကောက်ပွဲ':      
                        no_info_election_2010+=1
                    elif vote_val=='၂၀၁၂ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        no_info_election_2012+=1
                    elif vote_val=='၂၀၁၅ အထွေထွေရွေးကောက်ပွဲ':
                        no_info_election_2015+=1
                    elif vote_val=='၂၀၁၇ ကြားဖြတ်ရွေးကောက်ပွဲ':
                        no_info_election_2017+=1
                    elif vote_val=="၂၀၁၈ ကြားဖြတ်ရွေးကောက်ပွဲ":
                        no_info_election_2018+=1
                    elif vote_val=='၂၀၁၉ ရန်ကုန်စည်ပင်ရွေးကောက်ပွဲ':
                        no_info_election_2019+=1
                    elif vote_val=='မည်သည့်ရွေးကောက်ပွဲမှ မပေးဖူးပါ':
                        no_info_no_vote+=1

beforeVotemm_list.append([gender,female_election_2010,female_election_2012,female_election_2015,female_election_2017,female_election_2018,female_election_2019,female_no_vote])

beforeVotemm_list.append([gender,male_election_2010,male_election_2012,male_election_2015,male_election_2017,male_election_2018,male_election_2019,male_no_vote])

beforeVotemm_list.append([gender,other_election_2010,other_election_2012,other_election_2015,other_election_2017,other_election_2018,other_election_2019,other_no_vote])

beforeVotemm_list.append([gender,no_info_election_2010,no_info_election_2012,no_info_election_2015,no_info_election_2017,no_info_election_2018,no_info_election_2019,no_info_no_vote])


# Number of viewers in useful_useless page

beforeVotemm_pd = pd.DataFrame(beforeVotemm_list, columns = beforeVotemm_cols)
beforeVotemm_pd.to_csv(votemm_folder+'followup_asked_vote_by_user_.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    beforeVotemmFB_post=ans_one[5:6]
    for beforeVotemm in beforeVotemmFB_post:
        for before_v in beforeVotemm:
            if type(before_v) is not str:
                for before in before_v:
                    if gender=='female' or gender =='Female':
                        if before=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            female_follow_before+=1
                        elif before=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            female_like_before+=1
                        elif before=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            female_comment_before+=1
                        elif before=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            female_share_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            female_nopost_before+=1
                    elif gender=='Male' or gender=='male':
                        if before=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            male_follow_before+=1
                        elif before=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            male_like_before+=1
                        elif before=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            male_comment_before+=1
                        elif before=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            male_share_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            male_nopost_before+=1
                    elif gender=='other' or gender=='Other':
                        if before=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            other_follow_before+=1
                        elif before=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            other_like_before+=1
                        elif before=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            other_comment_before+=1
                        elif before=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            other_share_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            other_nopost_before+=1
                    else:
                        if before=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            no_info_follow_before+=1
                        elif before=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            no_info_like_before+=1
                        elif before=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            no_info_comment_before+=1
                        elif before=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            no_info_share_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            no_info_nopost_before+=1

beforeVotemmFB_list.append(["Female",female_follow_before,female_like_before,female_comment_before,female_share_before,female_nopost_before])

beforeVotemmFB_list.append(["Male",male_follow_before,male_like_before,male_comment_before,male_share_before,male_nopost_before])

beforeVotemmFB_list.append(["Other",other_follow_before,other_like_before,other_comment_before,other_share_before,other_nopost_before])

beforeVotemmFB_list.append(["No Info",no_info_follow_before,no_info_like_before,no_info_comment_before,no_info_share_before,no_info_nopost_before])

# Number of viewers in beforeVotemm FB page

beforeVotemmFB_pd = pd.DataFrame(beforeVotemmFB_list, columns = beforeVotemmFB_cols)
beforeVotemmFB_pd.to_csv(votemm_folder+'followup_before_votemm_post.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    afterVotemmFB_post=ans_one[7:8]
    for afterVotemm in afterVotemmFB_post:
        for after_v in afterVotemm:
            if type(after_v) is not str:
                for after in after_v:
                    if gender=='female' or gender =='Female':
                        if after=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            female_follow_before+=1
                        elif after=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            female_like_before+=1
                        elif after=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            female_comment_before+=1
                        elif after=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            female_share_before+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            female_nopost_before+=1
                    elif gender=='Male' or gender=='male':
                        if after=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            male_follow_before+=1
                        elif after=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            male_like_before+=1
                        elif after=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            male_comment_before+=1
                        elif after=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            male_share_before+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            male_nopost_before+=1
                    elif gender=='other' or gender=='Other':
                        if after=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            other_follow_before+=1
                        elif after=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            other_like_before+=1
                        elif after=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            other_comment_before+=1
                        elif after=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            other_share_before+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            other_nopost_before+=1
                    else:
                        if after=='စောင့်ကြည့် (follow လုပ်) ဖြစ်တယ်':
                            no_info_follow_before+=1
                        elif after=='"ကြိုက်" (like လုပ်) ဖြစ်တယ်':
                            no_info_like_before+=1
                        elif after=='"မှတ်ချက်ပေး" (comment ပေး) ပြီးဆွေးနွေးဖြစ်တယ်':
                            no_info_comment_before+=1
                        elif after=='"ဝေမျှ" (share  လုပ်) ပြီးဆွေးနွေးဖြစ်တယ်':
                            no_info_share_before+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            no_info_nopost_before+=1

afterVotemmFB_list.append(["Female",female_follow_before,female_like_before,female_comment_before,female_share_before,female_nopost_before])

afterVotemmFB_list.append(["Male",male_follow_before,male_like_before,male_comment_before,male_share_before,male_nopost_before])

afterVotemmFB_list.append(["Other",other_follow_before,other_like_before,other_comment_before,other_share_before,other_nopost_before])

afterVotemmFB_list.append(["No Info",no_info_follow_before,no_info_like_before,no_info_comment_before,no_info_share_before,no_info_nopost_before])

# Number of viewers in beforeVotemm FB post
afterVotemmFB_pd = pd.DataFrame(afterVotemmFB_list, columns = afterVotemmFB_cols)
afterVotemmFB_pd.to_csv(votemm_folder+'followup_after_votemm_post.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    beforeVotemm_opinion=ans_one[6:7]
    for beforeVotemm in beforeVotemm_opinion:
        for before_v in beforeVotemm:
            if type(before_v) is not str:
                for before in before_v:
                    if gender=='female' or gender=='Female':
                        if before=='စဉ်းစားဖြစ်တယ်': 
                            female_think_before+=1
                        elif before=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            female_group_discussion_before+=1
                        elif before=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            female_reveal_before+=1
                        elif before=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            female_make_decision_before+=1
                        elif before=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            female_make_encourage_before+=1
                        elif before=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            female_participate_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            female_none_before+=1
                    elif gender=='male' or gender=='Male':
                        if before=='စဉ်းစားဖြစ်တယ်': 
                            male_think_before+=1
                        elif before=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            male_group_discussion_before+=1
                        elif before=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            male_reveal_before+=1
                        elif before=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            male_make_decision_before+=1
                        elif before=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            male_make_encourage_before+=1
                        elif before=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            male_participate_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            male_none_before+=1
                    elif gender=='other' or gender=='Other':
                        if before=='စဉ်းစားဖြစ်တယ်': 
                            other_think_before+=1
                        elif before=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            other_group_discussion_before+=1
                        elif before=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            other_reveal_before+=1
                        elif before=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            other_make_decision_before+=1
                        elif before=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            other_make_encourage_before+=1
                        elif before=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            other_participate_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            other_none_before+=1
                    else:
                        if before=='စဉ်းစားဖြစ်တယ်': 
                            no_info_think_before+=1
                        elif before=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            no_info_group_discussion_before+=1
                        elif before=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            no_info_reveal_before+=1
                        elif before=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            no_info_make_decision_before+=1
                        elif before=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            no_info_make_encourage_before+=1
                        elif before=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            no_info_participate_before+=1
                        elif before=='ဘာမှမလုပ်ဖြစ်ပါ':
                            no_info_none_before+=1


beforeVotemm_opinion_list.append([gender,female_think_before,female_group_discussion_before,female_reveal_before,female_make_decision_before,female_make_encourage_before,female_participate_before,female_none_before])

beforeVotemm_opinion_list.append([gender,male_think_before,male_group_discussion_before,male_reveal_before,male_make_decision_before,male_make_encourage_before,male_participate_before,male_none_before])


beforeVotemm_opinion_list.append([gender,other_think_before,other_group_discussion_before,other_reveal_before,other_make_decision_before,other_make_encourage_before,other_participate_before,other_none_before])


beforeVotemm_opinion_list.append([gender,no_info_think_before,no_info_group_discussion_before,no_info_reveal_before,no_info_make_decision_before,no_info_make_encourage_before,no_info_participate_before,no_info_none_before])


# Number of viewers in beforeVotemm opinion post

beforeVotemm_opinion_pd = pd.DataFrame(beforeVotemm_opinion_list, columns = beforeVotemm_opinion_cols)
beforeVotemm_opinion_pd.to_csv(votemm_folder+'followup_beforevotemm_opinion.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    afterVotemm_opinion=ans_one[8:9]
    for afterVotemm in afterVotemm_opinion: 
        for after_v in afterVotemm:
            if type(after_v) is not str:
                for after in after_v:
                    if gender=='female' or gender=='Female':
                        if after=='စဉ်းစားဖြစ်တယ်': 
                            female_think_after+=1
                        elif after=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            female_group_discussion_after+=1
                        elif after=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            female_reveal_after+=1
                        elif after=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            female_make_decision_after+=1
                        elif after=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            female_make_encourage_after+=1
                        elif after=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            female_participate_after+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            female_none_after+=1
                    elif gender=='male' or gender=='Male':
                        if after=='စဉ်းစားဖြစ်တယ်': 
                            male_think_after+=1
                        elif after=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            male_group_discussion_after+=1
                        elif after=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            male_reveal_after+=1
                        elif after=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            male_make_decision_after+=1
                        elif after=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            male_make_encourage_after+=1
                        elif after=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            male_participate_after+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            male_none_after+=1
                    elif gender=='other' or gender=='Other':
                        if after=='စဉ်းစားဖြစ်တယ်': 
                            other_think_after+=1
                        elif after=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            other_group_discussion_after+=1
                        elif after=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            other_reveal_after+=1
                        elif after=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            other_make_decision_after+=1
                        elif after=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            other_make_encourage_after+=1
                        elif after=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            other_participate_after+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            other_none_after+=1
                    else:
                        if after=='စဉ်းစားဖြစ်တယ်': 
                            no_info_think_after+=1
                        elif after=='အသိုင်းအဝိုင်းနှင့်ဆွေးနွေးဖြစ်တယ်':
                            no_info_group_discussion_after+=1
                        elif after=='အများအတွက် ရေးသား ထုတ်ဖော်ဖြစ်တယ်':
                            no_info_reveal_after+=1
                        elif after=='မဲပေးရန်ဆုံးဖြတ်ဖြစ်တယ်':
                            no_info_make_decision_after+=1
                        elif after=='မဲပေးရန်တိုက်တွန်းဖြစ်တယ်':
                            no_info_make_encourage_after+=1
                        elif after=='တက်ကြွလှုပ်ရှားဖြစ်တယ်':
                            no_info_participate_after+=1
                        elif after=='ဘာမှမလုပ်ဖြစ်ပါ':
                            no_info_none_after+=1


afterVotemm_opinion_list.append(['Female',female_think_after,female_group_discussion_after,female_reveal_after,female_make_decision_after,female_make_encourage_after,female_participate_after,female_none_after])

afterVotemm_opinion_list.append(['Male',male_think_after,male_group_discussion_after,male_reveal_after,male_make_decision_after,male_make_encourage_after,male_participate_after,male_none_after])


afterVotemm_opinion_list.append(['Other',other_think_after,other_group_discussion_after,other_reveal_after,other_make_decision_after,other_make_encourage_after,other_participate_after,other_none_after])


afterVotemm_opinion_list.append(['No Info',no_info_think_after,no_info_group_discussion_after,no_info_reveal_after,no_info_make_decision_after,no_info_make_encourage_after,no_info_participate_after,no_info_none_after])

# Number of viewers in afterVotemm opinion post

afterVotemm_opinion_pd = pd.DataFrame(afterVotemm_opinion_list, columns = afterVotemm_opinion_cols)
afterVotemm_opinion_pd.to_csv(votemm_folder+'followup_aftervotemm_opinion.csv')

# %%
for client, gender,answer,count in followup_survey_df.itertuples(index=False):
    count_time = count
    gender=gender 
    ans_one=ast.literal_eval(answer)
    political_difficult=ans_one[9:10]
    for political in political_difficult:
        for politic in political:
            if type(politic) is not str:
                for pol in politic:
                    if gender=='female' or gender=="Female":
                        if pol=='စိတ်မဝင်စားလို့':
                            female_no_interest+=1
                        elif pol=='အချိန်/ငွေကြေးအခက်အခဲရှိလို့':
                            female_time_money_difficult+=1   
                        elif pol=='မိသားစု အသိုင်းအဝိုင်းက အားမပေးလို့':
                            female_family_disagreed+=1
                        elif pol=='နိုင်ငံရေးအကြောင်း အသိပညာ/အတွေ့အကြုံ အားနည်းလို့':
                            female_political_vulnerable+=1
                        elif pol=='တက်ကြွလှုပ်ရှားသူများနှင့် အချိတ်အဆက်မရှိလို့':
                            female_no_contact+=1
                        elif pol=='အဟန့်အတားမရှိပါ':
                            female_no_difficult+=1
                    elif gender=='male' or gender=="Male":
                        if pol=='စိတ်မဝင်စားလို့':
                            male_no_interest+=1
                        elif pol=='အချိန်/ငွေကြေးအခက်အခဲရှိလို့':
                            male_time_money_difficult+=1   
                        elif pol=='မိသားစု အသိုင်းအဝိုင်းက အားမပေးလို့':
                            male_family_disagreed+=1
                        elif pol=='နိုင်ငံရေးအကြောင်း အသိပညာ/အတွေ့အကြုံ အားနည်းလို့':
                            male_political_vulnerable+=1
                        elif pol=='တက်ကြွလှုပ်ရှားသူများနှင့် အချိတ်အဆက်မရှိလို့':
                            male_no_contact+=1
                        elif pol=='အဟန့်အတားမရှိပါ':
                            male_no_difficult+=1
                    elif gender=='other' or gender=="Other":
                        if pol=='စိတ်မဝင်စားလို့':
                            other_no_interest+=1
                        elif pol=='အချိန်/ငွေကြေးအခက်အခဲရှိလို့':
                            other_time_money_difficult+=1   
                        elif pol=='မိသားစု အသိုင်းအဝိုင်းက အားမပေးလို့':
                            other_family_disagreed+=1
                        elif pol=='နိုင်ငံရေးအကြောင်း အသိပညာ/အတွေ့အကြုံ အားနည်းလို့':
                            other_political_vulnerable+=1
                        elif pol=='တက်ကြွလှုပ်ရှားသူများနှင့် အချိတ်အဆက်မရှိလို့':
                            other_no_contact+=1
                        elif pol=='အဟန့်အတားမရှိပါ':
                            other_no_difficult+=1
                    else:
                        if pol=='စိတ်မဝင်စားလို့':
                            no_info_no_interest+=1
                        elif pol=='အချိန်/ငွေကြေးအခက်အခဲရှိလို့':
                            no_info_time_money_difficult+=1   
                        elif pol=='မိသားစု အသိုင်းအဝိုင်းက အားမပေးလို့':
                            no_info_family_disagreed+=1
                        elif pol=='နိုင်ငံရေးအကြောင်း အသိပညာ/အတွေ့အကြုံ အားနည်းလို့':
                            no_info_political_vulnerable+=1
                        elif pol=='တက်ကြွလှုပ်ရှားသူများနှင့် အချိတ်အဆက်မရှိလို့':
                            no_info_no_contact+=1
                        elif pol=='အဟန့်အတားမရှိပါ':
                            no_info_no_difficult+=1

votemm_difficult_list.append(["Female",female_no_interest,female_time_money_difficult,female_family_disagreed,female_political_vulnerable,female_no_contact,female_no_difficult])


votemm_difficult_list.append(["Male",male_no_interest,male_time_money_difficult,male_family_disagreed,male_political_vulnerable,male_no_contact,male_no_difficult])


votemm_difficult_list.append(["Other",other_no_interest,other_time_money_difficult,other_family_disagreed,other_political_vulnerable,other_no_contact,other_no_difficult])


votemm_difficult_list.append(["No Info",no_info_no_interest,no_info_time_money_difficult,no_info_family_disagreed,no_info_political_vulnerable,no_info_no_contact,no_info_no_difficult])

# Number of viewers in afterVotemm opinion post
votemm_difficult_pd = pd.DataFrame(votemm_difficult_list, columns = votemm_difficult_cols)
votemm_difficult_pd.to_csv(votemm_folder+'followup_political_obstacles.csv')
