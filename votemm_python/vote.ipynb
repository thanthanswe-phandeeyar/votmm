# %%
import pymongo
import pandas as pd 
from glob import glob 
import os
import numpy as np

# %%
# Update here

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["Votemm_20201014"]

# %%
print(myclient.list_database_names()) # Check a specific database by name
# Out:
# ['VoteMM_200918', 'VoteMM_200923', 'Votemm_20201014', 'admin', 'config', 'db_election', 'local', 'votemm', 'votemm_aug_1_31']

# %%
#Check if votemm exists
dblist = myclient.list_database_names()
if "Votemm_20201014" in dblist:
  print("Votemm_20201014 exists.")
# Out:
# Votemm_20201014 exists.

# %%
# Update here

vote_name =myclient.Votemm_20201014

voters = vote_name.voters

samples = voters.find().sort("_id",pymongo.ASCENDING)

voters_df = pd.DataFrame(samples)

voters_df.shape
# Out:
# (118068, 19)

# %%
vote_dataframe = pd.DataFrame (voters_df, columns = ['client_id','browser','os','gender','age','is_vote','not_vote_reason','pwd','ethnicity','regilion','submitSurvey'])

# %%
votemm_db ='Votemm_20201014/vote/'  # replace db-name 

votemm_folder = '../votemm_python/votemm/{}'.format(votemm_db) #create a folder with a respective database folder's name.

if not os.path.exists(votemm_folder):
    os.makedirs(votemm_folder)
else:votemm_path =votemm_folder

# %%
gender = vote_dataframe['gender']
female_count=male_count =other_count=no_info=0
vote_gender =[]
for gen in gender:
    if gen=='female':
        female_count+=1 
    elif gen=='male':
        male_count+=1
    elif gen=='other':
        other_count+=1
    else:no_info +=1 
vote_gender.append([female_count,male_count,other_count,no_info])
print(female_count,male_count,other_count,no_info)
# Number of voters by gender
vote_dataframe_gender = pd.DataFrame (vote_gender, columns = ['female','male','other','no_info'])
vote_dataframe_gender.to_csv(votemm_folder+'genders_by_users.csv')
# Out:
# 206 912 21 116929

# %%
pwd  = vote_dataframe[['pwd','gender']]
female_no=male_no=other_no=no_info_no=0
female_yes=male_yes=other_yes=no_info_yes=0
pwd_list=[]
for p_id,gender in pwd.itertuples(index=False):
    if p_id=='no':
        if gender =='female':
            female_no +=1
        elif gender=='male':
            male_no +=1
        elif gender=='other':
            other_no +=1
        else:
            no_info_no +=1
    elif p_id=='yes':
        if gender=='female':
            female_yes+=1
        elif gender=='male':
            male_yes+=1
        elif gender=='other':
            other_yes+=1
        else:
            no_info_yes +=1
    else:continue 
print(female_no,male_no,other_no,no_info_no,female_yes,male_yes,other_yes,no_info_yes)
pwd_list.append([female_no,male_no,other_no,no_info_no])
pwd_list.append([female_yes,male_yes,other_yes,no_info_yes])
# Number of voters by pwd

vote_gender_pwd = pd.DataFrame (pwd_list, columns = ['Female','Male','Other','No Info'])
vote_gender_pwd.to_csv(votemm_folder+'pwd_users_by_gender.csv')
# Out:
# 186 829 16 22 9 37 1 3

# %%
#### Religion
Religion_cols=['Gender','Decline','Buddhism','Islam','Hinduism','Christianity','Atheism']
vote_religion  = vote_dataframe[['client_id','gender','regilion']]

female_decline =female_buddhism=female_islam=female_hinduism=female_christianity=female_atheism=0
male_decline=male_buddhism=male_islam=male_hinduism=male_christianity=male_atheism=0
other_decline=other_buddhism=other_islam=other_hinduism=other_christianity=other_atheism=0
no_info_decline=no_info_buddhism=no_info_islam=no_info_hinduism=no_info_christianity=no_info_atheism=0

religion_list =[]

for client_id,gender, religion  in vote_religion.itertuples(index=False):
    client_id=client_id
    gender_id=gender 
    if gender_id=='female':
        if religion=='decline':female_decline+=1
        elif religion=='buddhism': female_buddhism+=1
        elif religion=='islam':female_islam+=1
        elif religion=='Hinduism':female_hinduism+=1
        elif religion=='Christianity': female_christianity+=1
        elif religion=='Atheism': female_atheism+=1
        else:pass
        religion_list.append([gender_id,female_decline,female_buddhism,female_islam,female_hinduism,female_christianity,female_atheism])
    elif gender=='male':
        if religion=='decline':male_decline+=1
        elif religion=='buddhism': male_buddhism+=1
        elif religion=='islam':male_islam+=1
        elif religion=='Hinduism':male_hinduism+=1
        elif religion=='Christianity': male_christianity+=1
        elif religion=='Atheism': male_atheism+=1
        else:pass
        religion_list.append([gender_id,male_decline,male_buddhism,male_islam,male_hinduism,male_christianity,male_atheism])
    elif gender=='other':
        if religion=='decline':other_decline+=1
        elif religion=='buddhism': other_buddhism+=1
        elif religion=='islam':other_islam+=1
        elif religion=='Hinduism':other_hinduism+=1
        elif religion=='Christianity': other_christianity+=1
        elif religion=='Atheism': other_atheism+=1
        else:pass 
        religion_list.append([gender_id,other_decline,other_buddhism,other_islam,other_hinduism,other_christianity,other_atheism])
    else:  ## no info 
        if religion=='decline':no_info_decline+=1
        elif religion=='buddhism': no_info_buddhism+=1
        elif religion=='islam':no_info_islam+=1
        elif religion=='Hinduism':no_info_hinduism+=1
        elif religion=='Christianity': no_info_christianity+=1
        elif religion=='Atheism': no_info_atheism+=1
        else:pass 
        religion_list.append([gender_id,no_info_decline,no_info_buddhism,no_info_islam,no_info_hinduism,no_info_christianity,no_info_atheism])
    

# # Number of voters by religion
vote_gender_religion = pd.DataFrame (religion_list, columns = Religion_cols)
vote_gender_religion.to_csv(votemm_folder+'religion_voters_by_gender.csv')

# %%
vote_dataframe.columns 

ethnicity =vote_dataframe.ethnicity.unique()
print(ethnicity)
# Out:
# [nan]

# %%
vote_ethnicity  = vote_dataframe[['client_id','gender','ethnicity']]
female_barma_count=female_barma_buddha_count=female_chin_count=female_myan_count=female_barma_tieyintha_count=female_paeye_count=female_kayin_count=female_barma_mus_count=female_mon_count=female_katoo_count=female_shan_barma=female_yawan=0
male_barma_count=male_barma_buddha_count=male_chin_count=male_myan_count=male_barma_tieyintha_count=male_paeye_count=male_kayin_count=male_barma_mus_count=male_mon_count=male_katoo_count=male_shan_barma=male_yawan=0
other_barma_count=other_barma_buddha_count=other_chin_count=other_myan_count=other_barma_tieyintha_count=other_paeye_count=other_kayin_count=other_barma_mus_count=other_mon_count=other_katoo_count=other_shan_barma=other_yawan=0
no_info_barma_count=no_info_barma_buddha_count=no_info_chin_count=no_info_myan_count=no_info_barma_tieyintha_count=no_info_paeye_count=no_info_kayin_count=no_info_barma_mus_count=no_info_mon_count=no_info_katoo_count=no_info_shan_barma=no_info_yawan=0
vote_ethnicity_list =[]


for client_id,gender, ethinic in vote_ethnicity.itertuples(index=False):
    client_id=client_id
    gender_id=gender 
    if gender_id=='female':
        if ethinic=='ဗမာ' or ethinic=='ကဗ်ား' or ethinic=='Burma' or ethinic=='burma' or ethinic=='Bamar' or ethinic=='Bama'or ethinic=='ဗမာတိုင်းရင်းသား':
            female_barma_count+=1 
        elif ethinic=='ဗာမာ ဗုဒ္ဓ':
            female_barma_buddha_count+=1
        elif ethinic=='ချင်း':
            female_chin_count+=1       
        elif ethinic=='Myanmar' or ethinic=='မြန်မာ' or ethinic=='myanmar' or ethinic=='မြန်မာလူမျိုး':
            female_myan_count+=1
        elif ethinic=='ဗမာတိုင်းရင်းသား':
            female_barma_tieyintha_count+=1
        elif ethinic=='ပအိုဝ်း' or ethinic=='ပသီ':
            female_paeye_count+=1
        elif ethinic=='ကရင်' or ethinic=='Kayin' : 
            female_kayin_count+=1
        elif ethinic=='ဗမာမွတ်စလင်':
            female_barma_mus_count+=1
        elif ethinic=='မွန်':
            female_mon_count +=1
        elif ethinic=='ကတူး':
            female_katoo_count+=1
        elif ethinic== 'ရှမ်း-ဗမာ':
            female_shan_barma+=1
        elif ethinic=='ရဝမ်' :
            female_yawan+=1
        else:pass
    elif gender_id=='male':
        if ethinic=='ဗမာ' or ethinic=='ကဗ်ား' or ethinic=='Burma' or ethinic=='burma' or ethinic=='Bamar' or ethinic=='Bama' or ethinic=='ဗမာတိုင်းရင်းသား':
            male_barma_count+=1 
        elif ethinic=='ဗာမာ ဗုဒ္ဓ':
            male_barma_buddha_count+=1
        elif ethinic=='ချင်း':male_chin_count+=1       
        elif ethinic=='Myanmar' or ethinic=='မြန်မာ' or ethinic=='myanmar' or ethinic=='မြန်မာလူမျိုး':
            male_myan_count+=1
        elif ethinic=='ဗမာတိုင်းရင်းသား':
            male_barma_tieyintha_count+=1
        elif ethinic=='ပအိုဝ်း' or ethinic=='ပသီ':
            male_paeye_count+=1
        elif ethinic=='ကရင်' or ethinic=='Kayin'  : 
            male_kayin_count+=1
        elif ethinic=='ဗမာမွတ်စလင်':
            male_barma_mus_count+=1
        elif ethinic=='မွန်':
            male_mon_count +=1
        elif ethinic=='ကတူး':
            male_katoo_count+=1
        elif ethinic== 'ရှမ်း-ဗမာ':
            male_shan_barma+=1
        elif ethinic=='ရဝမ်' :
            male_yawan+=1
        else:pass
    elif gender_id=='other':
        if ethinic=='ဗမာ' or ethinic=='ကဗ်ား' or ethinic=='Burma' or ethinic=='burma' or ethinic=='Bamar' or ethinic=='Bama' or ethinic=='ဗမာတိုင်းရင်းသား':
            other_barma_count+=1 
        elif ethinic=='ဗာမာ ဗုဒ္ဓ':
            other_barma_buddha_count+=1
        elif ethinic=='ချင်း':chin_count+=1       
        elif ethinic=='Myanmar' or ethinic=='မြန်မာ' or ethinic=='myanmar' or ethinic=='မြန်မာလူမျိုး':
            other_myan_count+=1
        elif ethinic=='ဗမာတိုင်းရင်းသား':
            other_barma_tieyintha_count+=1
        elif ethinic=='ပအိုဝ်း' or ethinic=='ပသီ':
            other_paeye_count+=1
        elif ethinic=='ကရင်' or ethinic=='Kayin'  : 
            other_kayin_count+=1
        elif ethinic=='ဗမာမွတ်စလင်':
            other_barma_mus_count+=1
        elif ethinic=='မွန်':
            other_mon_count +=1
        elif ethinic=='ကတူး':
            other_katoo_count+=1
        elif ethinic== 'ရှမ်း-ဗမာ':
            other_shan_barma+=1
        elif ethinic=='ရဝမ်' :
            other_yawan+=1
        else:pass
    else:
        if ethinic=='ဗမာ' or ethinic=='ကဗ်ား' or ethinic=='Burma' or ethinic=='burma' or ethinic=='Bamar' or ethinic=='Bama' or ethinic=='ဗမာတိုင်းရင်းသား':
            no_info_barma_count+=1 
        elif ethinic=='ဗာမာ ဗုဒ္ဓ':
            no_info_barma_buddha_count+=1
        elif ethinic=='ချင်း':
            no_info_chin_count+=1       
        elif ethinic=='Myanmar' or ethinic=='မြန်မာ' or ethinic=='myanmar' or ethinic=='မြန်မာလူမျိုး':
            no_info_myan_count+=1
        elif ethinic=='ဗမာတိုင်းရင်းသား':
            no_info_barma_tieyintha_count+=1
        elif ethinic=='ပအိုဝ်း' or ethinic=='ပသီ':
            no_info_paeye_count+=1
        elif ethinic=='ကရင်' or ethinic=='Kayin' : 
            no_info_kayin_count+=1
        elif ethinic=='ဗမာမွတ်စလင်':
            no_info_barma_mus_count+=1
        elif ethinic=='မွန်':
            no_info_mon_count +=1
        elif ethinic=='ကတူး':
            no_info_katoo_count+=1
        elif ethinic== 'ရှမ်း-ဗမာ':
            no_info_shan_barma+=1
        elif ethinic=='ရဝမ်' :
            no_info_yawan+=1
        else:pass



vote_ethnicity_list.append([female_barma_count,female_barma_buddha_count,female_chin_count,female_myan_count,female_barma_tieyintha_count,female_paeye_count,female_kayin_count,female_barma_mus_count,female_mon_count,female_katoo_count,female_shan_barma,female_yawan])
vote_ethnicity_list.append([male_barma_count,male_barma_buddha_count,male_chin_count,male_myan_count,male_barma_tieyintha_count,male_paeye_count,male_kayin_count,male_barma_mus_count,male_mon_count,male_katoo_count,male_shan_barma,male_yawan])
vote_ethnicity_list.append([other_barma_count,other_barma_buddha_count,other_chin_count,other_myan_count,other_barma_tieyintha_count,other_paeye_count,other_kayin_count,other_barma_mus_count,other_mon_count,other_katoo_count,other_shan_barma,other_yawan])
vote_ethnicity_list.append([no_info_barma_count,no_info_barma_buddha_count,no_info_chin_count,no_info_myan_count,no_info_barma_tieyintha_count,no_info_paeye_count,no_info_kayin_count,no_info_barma_mus_count,no_info_mon_count,no_info_katoo_count,no_info_shan_barma,no_info_yawan])

# # Number of voters by ethnicity
vote_gender_pwd = pd.DataFrame (vote_ethnicity_list, columns = ['Barma','Barma Buddha','Chin','Myanmar','Barma Tayintha','Pathi','Kayin','Barma Musilim','Mon','Katoo','ရှမ်း-ဗမာ','ရဝမ်'])
# # # vote_gender_pwd_df=vote_gender_pwd.groupby(['ethinicity','gender']).count()
vote_gender_pwd.to_csv(votemm_folder+'vote_ethinicity_by_gender.csv')

# %%
# Number of voters by age 
age_gender_df = vote_dataframe[['age','gender']]

age_gender =[]
eighteen_count=forty_five_count =thirty_count=sixty_count=noinfo_count=0
female_eighteen_count=male_eighteen_count =other_eighteen_count =0
female_forty_five=male_forty_five=other_forty_five =0
female_thirty = male_thirty=other_thirty=0
female_sixty=male_sixty=other_sixty =0
for age_count,gender in age_gender_df.itertuples(index=False):
    if age_count==18 or age_count=='18' or age_count==18.0:
        if gender =='female':female_eighteen_count+=1
        elif gender=='male':male_eighteen_count+=1
        elif gender=='other':other_eighteen_count+=1
    elif age_count==45 or age_count=='45' or age_count==45.0:
        if gender=='female':female_forty_five+=1
        elif gender =='male':male_forty_five+=1
        elif gender=='other':other_forty_five+=1
    elif age_count== 30 or age_count=='30' or age_count==30.0:
        if gender=='female':female_thirty+=1
        elif gender=='male':male_thirty+=1
        elif gender =='other':other_thirty+=1
    elif age_count==60 or age_count=='60' or age_count==60.0: 
        if gender=='female':female_sixty+=1
        elif gender=='male':male_sixty+=1
        elif gender=='other':other_sixty+=1

age_gender.append([female_eighteen_count,male_eighteen_count,other_eighteen_count])
age_gender.append([female_forty_five,male_forty_five,other_forty_five])
age_gender.append([female_thirty,male_thirty,other_thirty])
age_gender.append([female_sixty,male_sixty,other_sixty])

# Number of voters by age
vote_dataframe_age = pd.DataFrame (age_gender, columns = ['Age-Female','Age-Male','Age-Other'])
vote_dataframe_age.to_csv(votemm_folder+'vote_age_by_gender.csv')

# %%
is_vote_gender = vote_dataframe['is_vote']

# %%
is_vote_gender = vote_dataframe[['is_vote','gender']]

false_female = false_male=false_other=false_noinfo =0
true_female = true_male=true_other=true_noinfo=0
is_vote_list =[]

for is_vote,gender in is_vote_gender.itertuples(index=False):
    if is_vote  is not None:
        if is_vote=='true':
            if gender=='female':
                true_female+=1
            elif gender=='male':
                true_male+=1
            elif gender=='other':
                true_other+=1
            else:
                true_noinfo+=1
        elif is_vote=='false':
            if gender=='female' :
                false_female+=1
            elif gender=='male':
                false_male+=1
            elif gender=='other':
                false_other +=1
            else:
                false_noinfo+=1
    
is_vote_list.append(['true',true_female,true_male,true_other,true_noinfo])
is_vote_list.append(['false',false_female,false_male,false_other,false_noinfo])
# Number of voters by  is_vote
vote_dataframe_is_vote = pd.DataFrame (is_vote_list, columns = ['is_vote','Female','Male','Other','No Info'])
# # client_by_date=vote_dataframe_is_vote.groupby(['client_id'])['is_vote'].count()
vote_dataframe_is_vote.to_csv(votemm_folder+'is_vote_by_gender.csv')
# #

# %%
# # Number of voters by not vote reason
# vote_dataframe_is_vote = pd.DataFrame (vote_dataframe, columns = ['client_id','gender','not_vote_reason'])
# client_by_date=vote_dataframe_is_vote.groupby(['client_id','gender','not_vote_reason'])['not_vote_reason'].count()
# client_by_date.to_csv(votemm_folder+'not_vote_by_gender.csv')

# vote_dataframe['is_vote'].unique()

# %%
is_vote= vote_dataframe[['client_id','is_vote','gender','not_vote_reason']]

toofar_female=decline_female=invalid_female=not_interest_female=dontknow_female=busy_female=0
toofar_male=decline_male=invalid_male=not_interest_male=dontknow_male=busy_male=0

toofar_other=decline_other=invalid_other=not_interest_other=dontknow_other=busy_other=0
toofar_null=decline_null=invalid_null=not_interest_null=dontknow_null=busy_null=non_answer=0

nogender_noreason=is_vote_false=0

list_vote=[]

for client_id,is_vote,gender, not_vote_reason in is_vote.itertuples(index=False):
    client_id=client_id
    is_v=is_vote
    gender=gender
    not_vote_reason=not_vote_reason
    if is_v == 'false': 
        if gender =='female':     ### Female users
            if not_vote_reason=='toofar':toofar_female+=1
            elif not_vote_reason=='decline': decline_female+=1
            elif not_vote_reason=='invalid':invalid_female+=1
            elif not_vote_reason=='not_interest':not_interest_female+=1
            elif not_vote_reason=='dontknow':dontknow_female+=1
            elif not_vote_reason=='busy': busy_female+=1
            else:non_answer+=1

        elif gender=='male':      ### Male Users
            if not_vote_reason=='toofar':toofar_male+=1
            elif not_vote_reason=='decline': decline_male+=1
            elif not_vote_reason=='invalid':invalid_male+=1
            elif not_vote_reason=='not_interest':not_interest_male+=1
            elif not_vote_reason=='dontknow':dontknow_male+=1
            elif not_vote_reason=='busy': busy_male+=1
            else:non_answer+=1

        elif gender=='other':      ### Other Users
            if not_vote_reason=='toofar':toofar_other+=1
            elif not_vote_reason=='decline': decline_other+=1
            elif not_vote_reason=='invalid':invalid_other+=1
            elif not_vote_reason=='not_interest':not_interest_other+=1
            elif not_vote_reason=='dontknow':dontknow_other+=1
            elif not_vote_reason=='busy': busy_other+=1
            else:non_answer+=1

        else:           ## No Gender Users
            if not_vote_reason=='toofar':toofar_null+=1
            elif not_vote_reason=='decline': decline_null+=1
            elif not_vote_reason=='invalid':invalid_null+=1
            elif not_vote_reason=='not_interest':not_interest_null+=1
            elif not_vote_reason=='dontknow':dontknow_null+=1
            elif not_vote_reason=='busy': busy_null+=1
            else : non_answer+=1
        
    else:pass

list_vote.append(['female',toofar_female,decline_female,invalid_female,not_interest_female,dontknow_female,busy_female])
list_vote.append(['male',toofar_male,decline_male,invalid_male,not_interest_male,dontknow_male,busy_male])
list_vote.append(['other',toofar_other,decline_other,invalid_other,not_interest_other,dontknow_other,busy_other])
list_vote.append(['no info',toofar_null,decline_null,invalid_null,not_interest_null,dontknow_null,busy_null,non_answer])

# Numbers of voters (gender) by not vote reason
vote_dataframe_is_vote = pd.DataFrame (list_vote, columns = ['Gender','toofar','decline','invalid','not_interest','dontknow','busy','no answer'])
vote_dataframe_is_vote.to_csv(votemm_folder+'not_vote_reason_by_gender.csv')

# %%
## Vote timeline 

vote_timeline = vote_name.vote_timeline

vote_timeline_table = vote_timeline.find().sort("_id",pymongo.ASCENDING)

vote_timeline_df = pd.DataFrame(vote_timeline_table)

vote_timeline_df.shape

vote_timeline_df.columns
vote_timeline_df.is_vote.unique()
# Out:
# array([True, False, None, 'true', 'false', "true'"], dtype=object)

# %%
vote_time_line_gender_dataframe = pd.merge(vote_dataframe[['client_id']],vote_timeline_df)

vote_timeline_dataframe_by_gender=vote_time_line_gender_dataframe.groupby(['client_id'])['created_at'].count()

vote_timeline_dataframe_by_gender.to_csv(votemm_folder+'vote_timeline.csv')

# %%
vote_timeline_dataframe = pd.DataFrame (vote_timeline_df, columns = ['client_id','is_vote','updated_at','created_at'])
#with each client_id I am grouping based on "created date"
client_by_date=vote_timeline_dataframe.groupby(['client_id','is_vote'])['created_at'].count()
client_by_date.to_csv(votemm_folder+'vote_timeline_by_date.csv')

# %%
# Indicators

Indicators = vote_name.indicators

find = Indicators.inventory.find()

Indicators_table = Indicators.find().sort("_id",pymongo.ASCENDING)


Indicators_df = pd.DataFrame(Indicators_table)

Indicators_df.shape
# Out:
# (95159, 9)

# %%
client_id=Indicators_df.client_id.unique()  # no duplicate row
len(client_id)
# Out:
# 95159

# %%
Indicators_df.head()

Indicators_df.columns
# Out:
# Index(['_id', 'client_id', 'homePage', 'partyList', 'partyNameGame',
#        'visualization', 'glossary', 'updated_at', 'created_at'],
#       dtype='object')

# %%
home=[]
cols =['gender','partyList','candidates','election','station']
Indicators_dataframe = pd.merge(vote_dataframe[['client_id','gender']],Indicators_df)
home_df=Indicators_dataframe[["client_id","gender","homePage"]]

partyList_female = candidates_female = election_female = station_female =0
partyList_male = candidates_male = election_male = station_male =0
partyList_other = candidates_other = election_other = station_other =0
partyList_no_info = candidates_no_info = election_no_info = station_no_info =0

for client,gender, homePage in home_df.itertuples(index=False):
    client_id=client
    if gender =='female':
        for key,items in homePage.items():
            if items==None or items =='NaN':pass
            else:
                item = int(items)
                if key=="partyList": 
                    partyList_female+=item
                elif key=="candidates":
                    candidates_female+=item
                elif key=="election":
                    election_female+=item
                elif key=="station":
                    station_female+=item
    elif gender=='male':
        for key,items in homePage.items():
            if items==None or items =='NaN':pass
            else:
                item = int(items)
                if key=="partyList": 
                    partyList_male+=item
                elif key=="candidates":
                    candidates_male+=item
                elif key=="election":
                    election_male+=item
                elif key=="station":
                    station_male+=item
    elif gender=='other':
        for key,items in homePage.items():
            if items==None or items =='NaN':pass
            else:
                item = int(items)
                if key=="partyList": 
                    partyList_other+=item
                elif key=="candidates":
                    candidates_other+=item
                elif key=="election":
                    election_other+=item
                elif key=="station":
                    station_other+=item
    else:
        for key,items in homePage.items():
            if items==None or items =='NaN':pass
            else:
                item = int(items)
                if key=="partyList": 
                    partyList_no_info+=item
                elif key=="candidates":
                    candidates_no_info+=item
                elif key=="election":
                    election_no_info+=item
                elif key=="station":
                    station_no_info+=item

home.append(['female',partyList_female,candidates_female,election_female,station_female])
home.append(['male',partyList_male,candidates_male,election_male,station_male])
home.append(['other',partyList_other,candidates_other,election_other,station_other])
home.append(['no info',partyList_no_info,candidates_no_info,election_no_info,station_no_info])

home_Page = pd.DataFrame(home,columns=cols)
home_Page.to_csv(votemm_folder+'homePage_user_by_gender.csv')

# %%
party_dataframe = pd.merge(vote_dataframe[['client_id','gender']],Indicators_df)
party_list=[]
cols =['client_id','gender','New National Democracy Party', 'Shan-Ni Solidarity Party', 'Arakan National Party', 'Zo National Region Development', 'Mon Unity Party', 'Rakhine State National United Party','The Party for People', 'Women Party (Mon)', 'Union Solidarity and Development Party', 'Lisu National Development Party', 'Democratic Party of National Politics', 'Federal Union Party', 'National United Democratic Party','Ethnic National Development Party', 'Akha National Development Party', "People's Pioneer Party", 'Ta-Arng (Palaung) National Party', 'Inn National League Party', 'Shan Nationalities Democratic Party','Tai-Leng Nationalities Development Party', 'Party for Democracy and Peace ', 'Lhaovo National Unity and Development Party', 'Wun Thar Nu Democratic Party', 'National Democratic Force', 'Danu National Democracy Party', 'National Political Alliance League', 'Khumi (Khami) National Party', 'New Democracy Party (Kachin)', 'Ka Man National Development Party', 'Phlone-Sqaw Democratic Party', 'Kokang Democracy and Unity Party', 'National Prosperity Party', 'Democratic Party for a New Society', 'Pao National Organization', 'Kayah State Democratic  Party', 'Kayin Peoples Party', 'Public Contribute Students Party', 'Guiding Star Party','Asho Chin National Party', 'Daingnet National Development Party', 'National Unity Party', 'Democracy Party For Myanmar New Society', 'Inn National Development Party', 'National Development and Peace Party', 'People’s Party', '88 Generation Democracy Party', 'Modern People Party', 'Myanmar National Congress', 'Karen National Democratic  Party', 'La Hu National Development Party', 'Karen National Party', 'Mro National Development Party', 'National Unity Congress Party',"Myanmar People's Democratic Party", 'Myanmar Farmer’s Development Party', 'People Force Party', 'Dawei Nationalities Party', 'National Democratic Party for Development', 'Democratic Party(Myanmar)', 'Arakan Front Party', 'Chin National Party', 'Zomi Congress for Democracy', 'Union Farmer-Labour Force Party', 'Naga National Party', 'National Development Party', 'Kachin National Congress', 'Democracy and Human Rights Party', 'Chin National League For Democracy Party', 'The Yeomanry Development Party', 'Wa National Party', 'Peace for Diversity Party', 'National League for Democracy', 'Mro National Democracy Party', 'Kachin State People`s Party', 'Kachin National Party', 'Union Betterment Party', 'Danu National Organization Party', 'People`s Party of Myanmar Farmers And Workers', 'New Era Union Party', 'Mro Nationality Party', 'Kayan National Party', 'The 88 Generation Student Youths  (Union of Myanmar)', 'The Union of Myanmar Federation of National Politics', 'Alliance of Myanmar’s Worker and Farmer Party', 'Public of Labour Party', 'Arakan League for Democracy Party', 'New Society Party', 'Kha Me National Development Party', 'Union Pao National Organization', 'Bamar People`s Party', 'United Democratic Party', 'United Nationalities Democracy Party', 'Shan State Kokang Democratic Party', 'Shan Nationalities League for Democracy']


New_National_Democracy_Party=Shan_Ni_Solidarity_Party=Arakan_National_Party=Zo_National_Region_Development=Mon_Unity_Party=Rakhine_State_National_United_Party=0
The_Party_for_People=Women_Party_Mon=Union_Solidarity_and_Development_Party=Lisu_National_Development_Party=Democratic_Party_of_National_Politics=Federal_Union_Party=0
National_United_Democratic_Party=Ethnic_National_Development_Party=Akha_National_Development_Party=People_Pioneer_Party=Ta_Arng_Palaung_National_Party=0
Inn_National_League_Party=Shan_Nationalities_Democratic_Party=Tai_Leng_Nationalities_Development_Party=Party_for_Democracy_and_Peace=Lhaovo_National_Unity_and_Development_Party=0
Wun_Thar_Nu_Democratic_Party=National_Democratic_Force=Danu_National_Democracy_Party=National_Political_Alliance_League=Khumi_Khami_National_Party=New_Democracy_Party_Kachin=0
Ka_Man_National_Development_Party=Phlone_Sqaw_Democratic_Party=Kokang_Democracy_and_Unity_Party=National_Prosperity_Party=Democratic_Party_for_a_New_Society=0
Pao_National_Organization=Kayah_State_Democratic_Party=Kayin_Peoples_Party=Public_Contribute_Students_Party=Guiding_Star_Party=Asho_Chin_National_Party=0
Daingnet_National_Development_Party=National_Unity_Party=Democracy_Party_For_Myanmar_New_Society=Inn_National_Development_Party=National_Development_and_Peace_Party=0
People_Party=str_88_Generation_Democracy_Party=Modern_People_Party=Myanmar_National_Congress=Karen_National_Democratic_Party=La_Hu_National_Development_Party=0
Karen_National_Party=Mro_National_Development_Party=National_Unity_Congress_Party=Myanmar_People_Democratic_Party=Myanmar_Farmer_Development_Party=0
People_Force_Party=Dawei_Nationalities_Party=National_Democratic_Party_for_Development=Democratic_Party_Myanmar=Arakan_Front_Party=Chin_National_Party=0
Zomi_Congress_for_Democracy=Union_Farmer_Labour_Force_Party=Naga_National_Party=National_Development_Party=Kachin_National_Congress=0
Democracy_and_Human_Rights_Party=Chin_National_League_For_Democracy_Party=The_Yeomanry_Development_Party=Wa_National_Party=Peace_for_Diversity_Party=0
National_League_for_Democracy=Mro_National_Democracy_Party=Kachin_State_People_Party=Kachin_National_Party=Union_Betterment_Party=0
Danu_National_Organization_Party=People_Party_of_Myanmar_Farmers_And_Workers=New_Era_Union_Party=Mro_Nationality_Party=Kayan_National_Party=0
        The_88_Generation_Student_Youths_Union_of_Myanmar=The_Union_of_Myanmar_Federation_of_National_Politics=Alliance_of_Myanmar_Worker_and_Farmer_Party=0
Public_of_Labour_Party=Arakan_League_for_Democracy_Party=New_Society_Party=Kha_Me_National_Development_Party=Union_Pao_National_Organization=0
        Bamar_People_Party=United_Democratic_Party=United_Nationalities_Democracy_Party=Shan_State_Kokang_Democratic_Party=Shan_Nationalities_League_for_Democracy=0


party_df=party_dataframe[['client_id','gender','partyList']]
for client,gender, partyList in party_df.itertuples(index=False):
    client_id=client
    gender=gender 
    if partyList is not None:
        for key,items in partyList.items():
            if key=='New National Democracy Party':New_National_Democracy_Party=items
            elif key=='Shan-Ni Solidarity Party':Shan_Ni_Solidarity_Party =items
            elif key=='Arakan National Party':Arakan_National_Party =items
            elif key=='Zo National Region Development':Zo_National_Region_Development =items
            elif key=='Mon Unity Party':Mon_Unity_Party =items
            elif key=='Rakhine State National United Party':Rakhine_State_National_United_Party =items
            elif key=='The Party for People':The_Party_for_People=items
            elif key=='Women Party (Mon)':Women_Party_Mon =items
            elif key=='Union Solidarity and Development Party':Union_Solidarity_and_Development_Party=items
            elif key=='Lisu National Development Party':Lisu_National_Development_Party =items
            elif key=='Democratic Party of National Politics':Democratic_Party_of_National_Politics =items
            elif key=='Federal Union Party':Federal_Union_Party=items
            elif key=='National United Democratic Party':National_United_Democratic_Party =items
            elif key=='Ethnic National Development Party':Ethnic_National_Development_Party =items
            elif key=='Akha National Development Party':Akha_National_Development_Party = items
            elif key=="People's Pioneer Party":People_Pioneer_Party =items
            elif key=='Ta-Arng (Palaung) National Party':Ta_Arng_Palaung_National_Party =items
            elif key=='Inn National League Party':Inn_National_League_Party =items
            elif key=='Shan Nationalities Democratic Party':Shan_Nationalities_Democratic_Party =items
            elif key=='Tai-Leng Nationalities Development Party':Tai_Leng_Nationalities_Development_Party =items
            elif key=='Party for Democracy and Peace ' or key=='Party for Democracy and Peace':Party_for_Democracy_and_Peace =items
            elif key=='Lhaovo National Unity and Development Party':Lhaovo_National_Unity_and_Development_Party =items
            elif key=='Wun Thar Nu Democratic Party':Wun_Thar_Nu_Democratic_Party =items
            elif key=='National Democratic Force':National_Democratic_Force =items
            elif key=='Danu National Democracy Party':Danu_National_Democracy_Party =items
            elif key=='National Political Alliance League':National_Political_Alliance_League =items
            elif key=='Khumi (Khami) National Party':Khumi_Khami_National_Party =items
            elif key=='New Democracy Party (Kachin)':New_Democracy_Party_Kachin =items
            elif key=='Ka Man National Development Party':Ka_Man_National_Development_Party =items 
            elif key=='Phlone-Sqaw Democratic Party':Phlone_Sqaw_Democratic_Party =items
            elif key=='Kokang Democracy and Unity Party':Kokang_Democracy_and_Unity_Party =items 
            elif key=='National Prosperity Party':National_Prosperity_Party =items
            elif key=='Democratic Party for a New Society':Democratic_Party_for_a_New_Society =items
            elif key=='Pao National Organization':Pao_National_Organization =items
            elif key=='Kayah State Democratic  Party':Kayah_State_Democratic_Party =items
            elif key=='Kayin Peoples Party':Kayin_Peoples_Party =items 
            elif key=='Public Contribute Students Party':Public_Contribute_Students_Party =items 
            elif key=='Guiding Star Party':Guiding_Star_Party =items 
            elif key=='Asho Chin National Party':Asho_Chin_National_Party =items
            elif key=='Daingnet National Development Party':Daingnet_National_Development_Party =items
            elif key=='National Unity Party':National_Unity_Party =items
            elif key=='Democracy Party For Myanmar New Society':Democracy_Party_For_Myanmar_New_Society =items
            elif key=='Inn National Development Party':Inn_National_Development_Party =items
            elif key=='National Development and Peace Party':National_Development_and_Peace_Party =items
            elif key=='People’s Party':People_Party =items
            elif key=='88 Generation Democracy Party':str_88_Generation_Democracy_Party =items
            elif key=='Modern People Party':Modern_People_Party=items
            elif key=='Myanmar National Congress':Myanmar_National_Congress =items
            elif key=='Karen National Democratic  Party':Karen_National_Democratic_Party =items
            elif key=='La Hu National Development Party':La_Hu_National_Development_Party =items
            elif key=='Karen National Party':Karen_National_Party=items
            elif key== 'Mro National Development Party': Mro_National_Development_Party =items
            elif key=='National Unity Congress Party':National_Unity_Congress_Party =items
            elif key=="Myanmar People's Democratic Party":Myanmar_People_Democratic_Party =items
            elif key=='Myanmar Farmer’s Development Party':Myanmar_Farmer_Development_Party =items
            elif key=='People Force Party':People_Force_Party=items
            elif key=='Dawei Nationalities Party':Dawei_Nationalities_Party =items
            elif key=='National Democratic Party for Development':National_Democratic_Party_for_Development =items
            elif key=='Democratic Party(Myanmar)':Democratic_Party_Myanmar =items
            elif key=='Arakan Front Party':Arakan_Front_Party =items
            elif key=='Chin National Party':Chin_National_Party =items
            elif key=='Zomi Congress for Democracy':Zomi_Congress_for_Democracy =items
            elif key=='Union Farmer-Labour Force Party':Union_Farmer_Labour_Force_Party =items 
            elif key=='Naga National Party':Naga_National_Party =items
            elif key=='National Development Party':National_Development_Party =items
            elif key=='Kachin National Congress':Kachin_National_Congress =items
            elif key=='Democracy and Human Rights Party':Democracy_and_Human_Rights_Party =items
            elif key=='Chin National League For Democracy Party':Chin_National_League_For_Democracy_Party =items
            elif key=='The Yeomanry Development Party':The_Yeomanry_Development_Party =items
            elif key=='Wa National Party':Wa_National_Party =items
            elif key=='Peace for Diversity Party':Peace_for_Diversity_Party =items
            elif key=='National League for Democracy':National_League_for_Democracy =items
            elif key=='Mro National Democracy Party':Mro_National_Democracy_Party =items
            elif key=='Kachin State People`s Party':Kachin_State_People_Party =items
            elif key=='Kachin National Party':Kachin_National_Party =items
            elif key=='Union Betterment Party':Union_Betterment_Party =items
            elif key=='Danu National Organization Party':Danu_National_Organization_Party =items
            elif key== 'People`s Party of Myanmar Farmers And Workers': People_Party_of_Myanmar_Farmers_And_Workers =items
            elif key=='New Era Union Party':New_Era_Union_Party =items
            elif key=='Mro Nationality Party':Mro_Nationality_Party =items
            elif key=='Kayan National Party':Kayan_National_Party =items
            elif key=='The 88 Generation Student Youths  (Union of Myanmar)':The_88_Generation_Student_Youths_Union_of_Myanmar=items
            elif key=='The Union of Myanmar Federation of National Politics':The_Union_of_Myanmar_Federation_of_National_Politics =items
            elif key=='Alliance of Myanmar’s Worker and Farmer Party':Alliance_of_Myanmar_Worker_and_Farmer_Party =items
            elif key=='Public of Labour Party':Public_of_Labour_Party =items
            elif key=='Arakan League for Democracy Party':Arakan_League_for_Democracy_Party =items
            elif key=='New Society Party':New_Society_Party =items
            elif key=='Kha Me National Development Party':Kha_Me_National_Development_Party =items
            elif key=='Union Pao National Organization':Union_Pao_National_Organization =items
            elif key=='Bamar People`s Party':Bamar_People_Party =items
            elif key=='United Democratic Party':United_Democratic_Party =items
            elif key=='United Nationalities Democracy Party':United_Nationalities_Democracy_Party =items
            elif key=='Shan State Kokang Democratic Party':Shan_State_Kokang_Democratic_Party =items
            elif key=='Shan Nationalities League for Democracy':Shan_Nationalities_League_for_Democracy =items 
            else:continue 
        party_list.append([client_id,gender,New_National_Democracy_Party,Shan_Ni_Solidarity_Party,Arakan_National_Party,Zo_National_Region_Development,Mon_Unity_Party,Rakhine_State_National_United_Party,The_Party_for_People,Women_Party_Mon,Union_Solidarity_and_Development_Party,Lisu_National_Development_Party,Democratic_Party_of_National_Politics,Federal_Union_Party,National_United_Democratic_Party,Ethnic_National_Development_Party,Akha_National_Development_Party,People_Pioneer_Party,Ta_Arng_Palaung_National_Party,Inn_National_League_Party,Shan_Nationalities_Democratic_Party,Tai_Leng_Nationalities_Development_Party,Party_for_Democracy_and_Peace,Lhaovo_National_Unity_and_Development_Party,Wun_Thar_Nu_Democratic_Party,National_Democratic_Force,Danu_National_Democracy_Party,National_Political_Alliance_League,Khumi_Khami_National_Party,New_Democracy_Party_Kachin,Ka_Man_National_Development_Party,Phlone_Sqaw_Democratic_Party,Kokang_Democracy_and_Unity_Party,National_Prosperity_Party,Democratic_Party_for_a_New_Society,Pao_National_Organization,Kayah_State_Democratic_Party,Kayin_Peoples_Party,Public_Contribute_Students_Party,Guiding_Star_Party,Asho_Chin_National_Party,Daingnet_National_Development_Party,National_Unity_Party,Democracy_Party_For_Myanmar_New_Society,Inn_National_Development_Party,National_Development_and_Peace_Party,People_Party,str_88_Generation_Democracy_Party,Modern_People_Party,Myanmar_National_Congress,Karen_National_Democratic_Party,La_Hu_National_Development_Party,Karen_National_Party,Mro_National_Development_Party,National_Unity_Congress_Party,Myanmar_People_Democratic_Party,Myanmar_Farmer_Development_Party,People_Force_Party,Dawei_Nationalities_Party,National_Democratic_Party_for_Development,Democratic_Party_Myanmar,Arakan_Front_Party,Chin_National_Party,Zomi_Congress_for_Democracy,Union_Farmer_Labour_Force_Party,Naga_National_Party,National_Development_Party,Kachin_National_Congress,Democracy_and_Human_Rights_Party,Chin_National_League_For_Democracy_Party,The_Yeomanry_Development_Party,Wa_National_Party,Peace_for_Diversity_Party,National_League_for_Democracy,Mro_National_Democracy_Party,Kachin_State_People_Party,Kachin_National_Party,Union_Betterment_Party,Danu_National_Organization_Party,People_Party_of_Myanmar_Farmers_And_Workers,New_Era_Union_Party,Mro_Nationality_Party,Kayan_National_Party,The_88_Generation_Student_Youths_Union_of_Myanmar,The_Union_of_Myanmar_Federation_of_National_Politics,Alliance_of_Myanmar_Worker_and_Farmer_Party,Public_of_Labour_Party,Arakan_League_for_Democracy_Party,New_Society_Party,Kha_Me_National_Development_Party,Union_Pao_National_Organization,Bamar_People_Party,United_Democratic_Party,United_Nationalities_Democracy_Party,Shan_State_Kokang_Democratic_Party,Shan_Nationalities_League_for_Democracy])


Party_by_gender = pd.DataFrame(party_list,columns=cols)
Party_by_gender.to_csv(votemm_folder+'partylist_by_genders.csv')
# Out:
#   File "<ipython-input-25-cc2f7250144f>", line 21
#     The_88_Generation_Student_Youths_Union_of_Myanmar=The_Union_of_Myanmar_Federation_of_National_Politics=Alliance_of_Myanmar_Worker_and_Farmer_Party=0
#     ^
# IndentationError: unexpected indent

# %%
# Glossory by gender
glossary_dataframe = pd.merge(vote_dataframe[['client_id','gender']],Indicators_df)
glossary_list=[]

democracy_female=election_female=0
democracy_male=election_male=0
democracy_other=election_other=0
democracy_no_info=election_no_info=0

glos =['gender','democracy','election']
glossary_df=glossary_dataframe[["client_id","gender","glossary"]]
for client,gender, glossary in glossary_df.itertuples(index=False):
    client_id=client
    if gender=='female':
        for key,item in glossary.items():
            items= int(item)
            if key=="democracy": 
                democracy_female+=items
            elif key=="election":
                election_female+=items
    elif gender=='male':
        for key,item in glossary.items():
            items= int(item)
            if key=="democracy": 
                democracy_male+=items
            elif key=="election":
                election_male+=items
    elif gender=='other':
        for key,item in glossary.items():
            items= int(item)
            if key=="democracy": 
                democracy_other+=items
            elif key=="election":
                election_other+=items
    else:
        for key,item in glossary.items():
            items= int(item)
            if key=="democracy": 
                democracy_no_info+=items
            elif key=="election":
                election_no_info+=items
        
glossary_list.append(['female',democracy_female,election_female])
glossary_list.append(['male',democracy_male,election_male])
glossary_list.append(['other',democracy_other,election_other])
glossary_list.append(['no info',democracy_no_info,election_no_info])

glossary_pd = pd.DataFrame(glossary_list,columns=glos)
glossary_pd.to_csv(votemm_folder+'glossary_by_gender.csv')

# %%
# Visualization by gender

womenCandidate_female=noElection2015_female=noElection2010National_female=noElection2010Division_female=candidateByBarchart_female =0
womenCandidate_male=noElection2015_male=noElection2010National_male=noElection2010Division_male=candidateByBarchart_male =0
womenCandidate_other=noElection2015_other=noElection2010National_other=noElection2010Division_other=candidateByBarchart_other =0
womenCandidate_no_info=noElection2015_no_info=noElection2010National_no_info=noElection2010Division_no_info=candidateByBarchart_no_info =0

visualization_dataframe = pd.merge(vote_dataframe[['client_id','gender']],Indicators_df)
visualization_list =[]
visualization_cols  =['gender','womenCandidate','noElection2015','noElection2010National','noElection2010Division','candidateByBarchart']
visualization_df=visualization_dataframe[["client_id","gender","visualization"]]
for client,gender, visualization in visualization_df.itertuples(index=False):
    client_id=client
    if gender=='female':
        for key,item in visualization.items():
            items= int(item)
            if key=="womenCandidate": 
                womenCandidate_female+=items
            elif key=="noElection2015":
                noElection2015_female+=items
            elif key=="noElection2010National": 
                noElection2010National_female+=items
            elif key=="noElection2010Division":
                noElection2010Division_female+=items
            elif key=="candidateByBarchart": 
                candidateByBarchart_female+=items
    elif gender=='male':
        for key,item in visualization.items():
            items= int(item)
            if key=="womenCandidate": 
                womenCandidate_male+=items
            elif key=="noElection2015":
                noElection2015_male+=items
            elif key=="noElection2010National": 
                noElection2010National_male+=items
            elif key=="noElection2010Division":
                noElection2010Division_male+=items
            elif key=="candidateByBarchart": 
                candidateByBarchart_male+=items
    elif gender=='other':
        for key,item in visualization.items():
            items= int(item)
            if key=="womenCandidate": 
                womenCandidate_other+=items
            elif key=="noElection2015":
                noElection2015_other+=items
            elif key=="noElection2010National": 
                noElection2010National_other+=items
            elif key=="noElection2010Division":
                noElection2010Division_other+=items
            elif key=="candidateByBarchart": 
                candidateByBarchart_other+=items
    else:
        for key,item in visualization.items():
            items= int(item)
            if key=="womenCandidate": 
                womenCandidate_no_info+=items
            elif key=="noElection2015":
                noElection2015_no_info+=items
            elif key=="noElection2010National": 
                noElection2010National_no_info+=items
            elif key=="noElection2010Division":
                noElection2010Division_no_info+=items
            elif key=="candidateByBarchart": 
                candidateByBarchart_no_info+=items

visualization_list.append(['female',womenCandidate_female,noElection2015_female,noElection2010National_female,noElection2010Division_female,candidateByBarchart_female])
visualization_list.append(['male',womenCandidate_male,noElection2015_male,noElection2010National_male,noElection2010Division_male,candidateByBarchart_male])
visualization_list.append(['other',womenCandidate_other,noElection2015_other,noElection2010National_other,noElection2010Division_other,candidateByBarchart_other])
visualization_list.append(['no_info',womenCandidate_no_info,noElection2015_no_info,noElection2010National_no_info,noElection2010Division_no_info,candidateByBarchart_no_info])

visualization_by_gender = pd.DataFrame(visualization_list,columns=visualization_cols)

visualization_by_gender.to_csv(votemm_folder+'visualization_by_gender.csv')

# %%
# partyGameNames
partyGameName_dataframe = pd.merge(vote_dataframe[['client_id','gender']],Indicators_df)
partygames_list=[]
partyGameName =['gender','intro','result']
partyNameGame_df=partyGameName_dataframe[["client_id","gender","partyNameGame"]]

intro_female=result_female=0
intro_male=result_male=0
intro_other=result_other=0
intro_no_info=result_no_info=0

for client,gender, partyName in partyNameGame_df.itertuples(index=False):
    client_id=client
    if gender =='female':
        for key,item in partyName.items():
            items= int(item)
            if key=="intro": 
                intro_female +=items
            elif key=="result":
                result_female+=items
    elif gender =='male':
        for key,item in partyName.items():
            items= int(item)
            if key=="intro": 
                intro_male +=items
            elif key=="result":
                result_male+=items
    elif gender =='other':
        for key,item in partyName.items():
            items= int(item)
            if key=="intro": 
                intro_other +=items
            elif key=="result":
                result_other +=items
    else:
        for key,item in partyName.items():
            items= int(item)
            if key=="intro": 
                intro_no_info +=items
            elif key=="result":
                result_no_info +=items

partygames_list.append(['female',intro_female,result_female])
partygames_list.append(['male',intro_male,result_male])
partygames_list.append(['other',intro_other,result_other])
partygames_list.append(['no info',intro_no_info,result_no_info])

partygames_list_client_by_gender = pd.DataFrame(partygames_list,columns=partyGameName)
partygames_list_client_by_gender.to_csv(votemm_folder+'partyNameGames_by_genders.csv')
